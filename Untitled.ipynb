# %%
import pandas as pd

# %%
#declarar un data frame
DF = pd.DataFrame(data = data, 
                  columns=["columnsname"], 
                  index=[list])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fcbb52ef4256> in <module>
#       1 #declarar un data frame
# ----> 2 DF = pd.DataFrame(data = data,
#       3                   columns=["columnsname"],
#       4                   index=[list])
#
# NameError: name 'data' is not defined

# %%
antidiabeticos = ["Metformina", "Glimepirida", "Glibenclamida"]

# %%
dosis_antidiabeticos = [500, 4, 12]

# %%
#merge 2 listas
data = [antidiabeticos, dosis_antidiabeticos]

# %%
import numpy as np
data = np.transpose(data, axes = None)
data
# Out:
# array([['Metformina', '500'],
#        ['Glimepirida', '4'],
#        ['Glibenclamida', '12']], dtype='<U13')

# %%
#declarar un data frame
DF = pd.DataFrame(data = data, 
                  columns=["farmaco", "dosis"], 
                  )

# %%
DF
# Out:
#          farmaco dosis
# 0     Metformina   500
# 1    Glimepirida     4
# 2  Glibenclamida    12

# %%
#Asignar una columna como indice
DF = DF.set_index("farmaco")
DF
# Out:
#               dosis
# farmaco
# Metformina      500
# Glimepirida       4
# Glibenclamida    12

# %%
#Crear DF a partir de diccionarios
data1 = {
    "farmacos": antidiabeticos,
    "dosis" : dosis_antidiabeticos
}

# %%
DF2 = pd.DataFrame.from_dict(data1)

# %%
DF2
# Out:
#         farmacos  dosis
# 0     Metformina    500
# 1    Glimepirida      4
# 2  Glibenclamida     12

# %%
#Visualizaciones

# %%
DF2.head()
# Out:
#         farmacos  dosis
# 0     Metformina    500
# 1    Glimepirida      4
# 2  Glibenclamida     12

# %%
DF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# farmacos    3 non-null object
# dosis       3 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 128.0+ bytes

# %%
#Visualizar el nombre de las columnas
DF2.columns
# Out:
# Index(['farmacos', 'dosis'], dtype='object')

# %%
#Visualizar una columna

# %%
DF2.dosis
# Out:
# 0    500
# 1      4
# 2     12
# Name: dosis, dtype: int64

# %%
#convertir columna en lista
lista_dosis = DF2.dosis.to_list()
lista_dosis
# Out:
# [500, 4, 12]

# %%
DF2["dosis"]
# Out:
# 0    500
# 1      4
# 2     12
# Name: dosis, dtype: int64

# %%
#anexar una columna a DF2
DF2["antirritmicos"] = ["Metoprolol", "captopril", "Amiodaro"]

# %%
DF2
# Out:
#         farmacos  dosis antirritmicos
# 0     Metformina    500    Metoprolol
# 1    Glimepirida      4     captopril
# 2  Glibenclamida     12      Amiodaro

# %%
#Borrar una columns
DF2 = DF2.drop("antirritmicos", axis = 1)

# %%
DF2
# Out:
#         farmacos  dosis
# 0     Metformina    500
# 1    Glimepirida      4
# 2  Glibenclamida     12

# %%
#Guardar como .csv
DF2.to_csv("antidiabeticos.csv", sep = ",")

# %%
#Open a csv as DataFrame

# %%
DF = pd.read_csv("Data_SVM.csv", sep = "," )

# %%
DF
# Out:
#       #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 0                         0                  7               3            85
# 1                         0                 27              14            83
# 2                         0                 26              14            83
# 3                         6                 14               3            79
# 4                         6                  8               3            67
# 5                        18                  4               1            65
# 6                        36                 17              14            62
# 7                        24                  8               5            58
# 8                        24                  8               6            58
# 9                        16                  7               4            58
# 10                       26                 10               7            57
# ...

# %%
DF.head()
# Out:
#    #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 0                      0                  7               3            85
# 1                      0                 27              14            83
# 2                      0                 26              14            83
# 3                      6                 14               3            79
# 4                      6                  8               3            67
#
#    #Rotatable bonds           Ali Class  Ali Log S  Ali Solubility (mg/ml)  \
# 0                52           Insoluble     -32.61            2.960000e-30
# 1                19  Moderately soluble      -5.13            8.840000e-03
# 2                17      Poorly soluble      -6.01            1.170000e-03
# 3                63           Insoluble     -27.92            1.350000e-25
# 4                54           Insoluble     -26.06            8.140000e-24
#
# ...

# %%
DF.shape
# Out:
# (2016, 54)

# %%
DF.columns
# Out:
# Index(['#Aromatic heavy atoms', '#H-bond acceptors', '#H-bond donors',
#        '#Heavy atoms', '#Rotatable bonds', 'Ali Class', 'Ali Log S',
#        'Ali Solubility (mg/ml)', 'Ali Solubility (mol/l)', 'BBB permeant',
#        'Bioavailability Score', 'Brenk #alerts', 'CYP1A2 inhibitor',
#        'CYP2C19 inhibitor', 'CYP2C9 inhibitor', 'CYP2D6 inhibitor',
#        'CYP3A4 inhibitor', 'Canonical SMILES', 'Consensus Log P', 'Drug Like',
#        'ESOL Class', 'ESOL Log S', 'ESOL Solubility (mg/ml)',
#        'ESOL Solubility (mol/l)', 'Egan #violations', 'Formula',
#        'Fraction Csp3', 'GI absorption', 'Ghose #violations', 'ID_Database',
#        'Input Smiles', 'Leadlikeness #violations', 'Library',
#        'Lipinski #violations', 'MLOGP', 'MR', 'MW', 'Molecule',
#        'Muegge #violations', 'Name', 'PAINS #alerts', 'Pgp substrate',
#        'Silicos-IT Log P', 'Silicos-IT LogSw', 'Silicos-IT Solubility (mg/ml)',
#        'Silicos-IT Solubility (mol/l)', 'Silicos-IT class',
# ...

# %%
#Ver elementos repetidos de una columna
DF.Library.unique()
# Out:
# array(['Afro', 'Biofacquim', 'FDA'], dtype=object)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 54 columns):
# #Aromatic heavy atoms            2016 non-null int64
# #H-bond acceptors                2016 non-null int64
# #H-bond donors                   2016 non-null int64
# #Heavy atoms                     2016 non-null int64
# #Rotatable bonds                 2016 non-null int64
# Ali Class                        2016 non-null object
# Ali Log S                        2016 non-null float64
# Ali Solubility (mg/ml)           2016 non-null float64
# Ali Solubility (mol/l)           2016 non-null float64
# BBB permeant                     2016 non-null object
# Bioavailability Score            2016 non-null float64
# Brenk #alerts                    2016 non-null int64
# CYP1A2 inhibitor                 2016 non-null object
# CYP2C19 inhibitor                2016 non-null object
# CYP2C9 inhibitor                 2016 non-null object
# ...

# %%
DF["#H-bond acceptors"].describe()
# Out:
# count    2016.000000
# mean        5.093750
# std         4.051608
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        47.000000
# Name: #H-bond acceptors, dtype: float64

# %%
#columnas con variables numericas
DF.select_dtypes(np.number)
# Out:
#       #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 0                         0                  7               3            85
# 1                         0                 27              14            83
# 2                         0                 26              14            83
# 3                         6                 14               3            79
# 4                         6                  8               3            67
# 5                        18                  4               1            65
# 6                        36                 17              14            62
# 7                        24                  8               5            58
# 8                        24                  8               6            58
# 9                        16                  7               4            58
# 10                       26                 10               7            57
# ...

# %%
#ver variables con datos flotantes
DF.select_dtypes("float64")
# Out:
#       Ali Log S  Ali Solubility (mg/ml)  Ali Solubility (mol/l)  \
# 0        -32.61            2.960000e-30            2.480000e-33
# 1         -5.13            8.840000e-03            7.400000e-06
# 2         -6.01            1.170000e-03            9.800000e-07
# 3        -27.92            1.350000e-25            1.210000e-28
# 4        -26.06            8.140000e-24            8.630000e-27
# 5         -8.31            4.260000e-06            4.940000e-09
# 6         -9.89            1.100000e-07            1.290000e-10
# 7        -16.33            3.700000e-14            4.730000e-17
# 8        -16.66            1.710000e-14            2.190000e-17
# 9        -20.55            2.260000e-18            2.820000e-21
# 10       -11.04            7.090000e-09            9.170000e-12
# 11       -11.61            1.890000e-09            2.450000e-12
# 12       -15.55            2.290000e-13            2.830000e-16
# 13       -13.16            5.240000e-11            6.930000e-14
# ...

# %%
#ver elementos repetidos
DF.Library.unique()
# Out:
# array(['Afro', 'Biofacquim', 'FDA'], dtype=object)

# %%
DF.Library.value_counts()
# Out:
# Afro          903
# FDA           690
# Biofacquim    423
# Name: Library, dtype: int64

# %%
nuevas_variables = ["Library", '#Heavy atoms']

# %%
#ver un data frame que tenga solo variables deseadas
new_DF = DF[nuevas_variables]

# %%
new_DF.head()
# Out:
#   Library  #Heavy atoms
# 0    Afro            85
# 1    Afro            83
# 2    Afro            83
# 3    Afro            79
# 4    Afro            67

# %%
Biofacquim = DF[DF["Library"]=="Biofacquim"]

# %%
Biofacquim.describe()
# Out:
#        #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# count             423.000000         423.000000      423.000000    423.000000
# mean                7.021277           6.751773        2.621749     29.177305
# std                 6.519168           6.785637        3.319296     20.478616
# min                 0.000000           0.000000        0.000000      0.000000
# 25%                 0.000000           3.000000        1.000000     19.000000
# 50%                 6.000000           5.000000        2.000000     24.000000
# 75%                12.000000           7.000000        3.000000     33.000000
# max                36.000000          47.000000       19.000000    174.000000
#
#        #Rotatable bonds   Ali Log S  Ali Solubility (mg/ml)  \
# count        423.000000  423.000000            4.230000e+02
# mean           6.085106   -5.441418            8.841148e+00
# std            8.605484    3.805095            1.099276e+02
# ...

# %%
DF.describe()
# Out:
#        #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# count            2016.000000        2016.000000     2016.000000   2016.000000
# mean                8.267361           5.093750        1.997024     26.053571
# std                 6.596371           4.051608        2.221705     12.555588
# min                 0.000000           0.000000        0.000000      0.000000
# 25%                 0.000000           3.000000        1.000000     19.000000
# 50%                 6.000000           4.000000        1.500000     24.000000
# 75%                12.000000           6.000000        3.000000     30.000000
# max                36.000000          47.000000       19.000000    174.000000
#
#        #Rotatable bonds    Ali Log S  Ali Solubility (mg/ml)  \
# count       2016.000000  2016.000000            2.016000e+03
# mean           4.527778    -4.785933            1.907376e+01
# std            5.690550     3.109305            2.511777e+02
# ...

# %%
DF[DF["#H-bond acceptors"]>15]
# Out:
#       #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 1                         0                 27              14            83
# 2                         0                 26              14            83
# 6                        36                 17              14            62
# 20                       22                 18              11            55
# 22                        0                 16               2            53
# 74                       16                 17              11            44
# 76                       16                 16               9            44
# 77                       22                 16              10            44
# 80                       16                 16              10            43
# 81                       16                 16              10            43
# 1012                      0                 16               8            49
# ...

# %%
DF[DF["#H-bond acceptors"]>15].shape
# Out:
# (40, 54)

# %%
TWO conditions
# Out:
#   File "<ipython-input-92-bbb52f20f40f>", line 1
#     TWO conditions
#                  ^
# SyntaxError: invalid syntax

# %%
DF_2busquedas = DF[(DF["Library"]=="FDA")&(DF["#H-bond acceptors"]  < 5)]

# %%
DF_2busquedas
# Out:
#       #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 1326                      0                  2               2            11
# 1327                     12                  4               1            19
# 1328                      0                  3               2             9
# 1329                      0                  3               2             9
# 1330                      0                  2               0            10
# 1331                      6                  2               1            13
# 1333                      9                  0               1            10
# 1334                      9                  4               3            21
# 1335                      6                  2               1            26
# 1336                      0                  4               2            11
# 1337                      0                  3               0            12
# ...

# %%
#Reset index
DF_2busquedas = DF_2busquedas.reset_index()
DF_2busquedas = DF_2busquedas.drop("index", axis = 1)
DF_2busquedas
# Out:
#      level_0  #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  \
# 0          0                      0                  2               2
# 1          1                     12                  4               1
# 2          2                      0                  3               2
# 3          3                      0                  3               2
# 4          4                      0                  2               0
# 5          5                      6                  2               1
# 6          6                      9                  0               1
# 7          7                      9                  4               3
# 8          8                      6                  2               1
# 9          9                      0                  4               2
# 10        10                      0                  3               0
# 11        11                      6                  2               2
# ...

# %%
#Visualizar filas
DF.loc[:13]
# Out:
#     #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 0                       0                  7               3            85
# 1                       0                 27              14            83
# 2                       0                 26              14            83
# 3                       6                 14               3            79
# 4                       6                  8               3            67
# 5                      18                  4               1            65
# 6                      36                 17              14            62
# 7                      24                  8               5            58
# 8                      24                  8               6            58
# 9                      16                  7               4            58
# 10                     26                 10               7            57
# ...

# %%
#visualizar una celda
DF.loc[1]["Library"]
# Out:
# 'Afro'

# %%
#Por posicion iloc (por el indice)
DF.iloc[0]["Library"]
# Out:
# 'Afro'

# %%
#Missing Data

# %%
DF_MD = pd.read_csv("DF_MissingData.csv", sep = ",")

# %%
DF_MD.isnull()
# Out:
#      #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                False            True          True             False
# 1                False           False         False             False
# 2                False           False         False             False
# 3                False           False         False             False
# 4                False           False         False             False
# 5                False           False         False             False
# 6                False           False         False             False
# 7                False           False         False             False
# 8                False           False         False             False
# 9                False           False         False             False
# 10               False           False         False             False
# 11               False           False         False             False
# ...
