# %% [markdown]
# Pandas
#
# Is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
# https://pandas.pydata.org/pandas-docs/stable/

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create a DataFrame

# %% [markdown]
# DF = pd.DataFrame(data = data, columns=["columnsname"], index=[list])

# %%
antidiabeticos = ["Metformina", "Glimepirida"," Empagliflozina"]

# %%
dosis_antidiabeticos = [500, 4, 12]

# %%
antihipertensivos = ["Atenolol", "Captopril", "Enalapril"]

# %%
dosis_antihipertensivos = [10,50, 20 ]

# %% [markdown]
# merge data into a list

# %%
data = [antidiabeticos, dosis_antidiabeticos, antihipertensivos, dosis_antihipertensivos]

# %%
data = np.transpose(data, axes = None)

# %% [markdown]
# write Data Frame

# %%
DF1 = pd.DataFrame( data = data,
                    columns = ["antidiabeticos", "dosis", "antihipertensivo", "dosis"])

# %% [markdown]
# Visualize DataFrame

# %%
DF1
# Out:
#     antidiabeticos dosis antihipertensivo dosis
# 0       Metformina   500         Atenolol    10
# 1      Glimepirida     4        Captopril    50
# 2   Empagliflozina    12        Enalapril    20

# %%
DF1.head()
# Out:
#     antidiabeticos dosis antihipertensivo dosis
# 0       Metformina   500         Atenolol    10
# 1      Glimepirida     4        Captopril    50
# 2   Empagliflozina    12        Enalapril    20

# %% [markdown]
# visualize a column

# %%
DF1.antidiabeticos
# Out:
# 0         Metformina
# 1        Glimepirida
# 2     Empagliflozina
# Name: antidiabeticos, dtype: object

# %%
DF1["antidiabeticos"]
# Out:
# 0         Metformina
# 1        Glimepirida
# 2     Empagliflozina
# Name: antidiabeticos, dtype: object

# %% [markdown]
# Data frame from a dictionary

# %%
data_dict = {
    "antidiabeticos":antidiabeticos,
    "dosis antidiabeticos": dosis_antidiabeticos,
    "antihipertensivos": antihipertensivos,
    "dosis antihipertensivos": dosis_antihipertensivos
}

# %%
#data_dict["antidiabeticos"]

# %%
DF2 = pd.DataFrame.from_dict(data_dict)

# %%
DF2
# Out:
#     antidiabeticos  dosis antidiabeticos antihipertensivos  \
# 0       Metformina                   500          Atenolol
# 1      Glimepirida                     4         Captopril
# 2   Empagliflozina                    12         Enalapril
#
#    dosis antihipertensivos
# 0                       10
# 1                       50
# 2                       20

# %% [markdown]
# Create a new column

# %%
DF2["antirritmicos"] = ["Metoprolol", "Amiodarona", "Diltiazem" ]

# %%
DF2
# Out:
#     antidiabeticos  dosis antidiabeticos antihipertensivos  \
# 0       Metformina                   500          Atenolol
# 1      Glimepirida                     4         Captopril
# 2   Empagliflozina                    12         Enalapril
#
#    dosis antihipertensivos antirritmicos
# 0                       10    Metoprolol
# 1                       50    Amiodarona
# 2                       20     Diltiazem

# %% [markdown]
# save a data frame as csv file

# %%
DF2.to_csv("MyfirstDF.csv", sep = ",")

# %% [markdown]
# # Open a csv file as DataFrame

# %%
DF = pd.read_csv("Data.csv")

# %%
DF.head()
# Out:
#    #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 0                      0                  7               3            85
# 1                      0                 27              14            83
# 2                      0                 26              14            83
# 3                      6                 14               3            79
# 4                      6                  8               3            67
#
#    #Rotatable bonds           Ali Class  Ali Log S  Ali Solubility (mg/ml)  \
# 0                52           Insoluble     -32.61            2.960000e-30
# 1                19  Moderately soluble      -5.13            8.840000e-03
# 2                17      Poorly soluble      -6.01            1.170000e-03
# 3                63           Insoluble     -27.92            1.350000e-25
# 4                54           Insoluble     -26.06            8.140000e-24
#
# ...

# %% [markdown]
# # Data Frame information

# %% [markdown]
# Figure out column data type

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 54 columns):
# #Aromatic heavy atoms            2016 non-null int64
# #H-bond acceptors                2016 non-null int64
# #H-bond donors                   2016 non-null int64
# #Heavy atoms                     2016 non-null int64
# #Rotatable bonds                 2016 non-null int64
# Ali Class                        2016 non-null object
# Ali Log S                        2016 non-null float64
# Ali Solubility (mg/ml)           2016 non-null float64
# Ali Solubility (mol/l)           2016 non-null float64
# BBB permeant                     2016 non-null object
# Bioavailability Score            2016 non-null float64
# Brenk #alerts                    2016 non-null int64
# CYP1A2 inhibitor                 2016 non-null object
# CYP2C19 inhibitor                2016 non-null object
# CYP2C9 inhibitor                 2016 non-null object
# ...

# %% [markdown]
# compute statistical values

# %%
DF.describe()
# Out:
#        #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# count            2016.000000        2016.000000     2016.000000   2016.000000
# mean                8.267361           5.093750        1.997024     26.053571
# std                 6.596371           4.051608        2.221705     12.555588
# min                 0.000000           0.000000        0.000000      0.000000
# 25%                 0.000000           3.000000        1.000000     19.000000
# 50%                 6.000000           4.000000        1.500000     24.000000
# 75%                12.000000           6.000000        3.000000     30.000000
# max                36.000000          47.000000       19.000000    174.000000
#
#        #Rotatable bonds    Ali Log S  Ali Solubility (mg/ml)  \
# count       2016.000000  2016.000000            2.016000e+03
# mean           4.527778    -4.785933            1.907376e+01
# std            5.690550     3.109305            2.511777e+02
# ...

# %% [markdown]
# data frame row and columns

# %%
DF.shape
# Out:
# (2016, 54)

# %% [markdown]
# columns with numeric data

# %%
DF.select_dtypes(np.number)
# Out:
#       #Aromatic heavy atoms  #H-bond acceptors  #H-bond donors  #Heavy atoms  \
# 0                         0                  7               3            85
# 1                         0                 27              14            83
# 2                         0                 26              14            83
# 3                         6                 14               3            79
# 4                         6                  8               3            67
# 5                        18                  4               1            65
# 6                        36                 17              14            62
# 7                        24                  8               5            58
# 8                        24                  8               6            58
# 9                        16                  7               4            58
# 10                       26                 10               7            57
# ...

# %%
DF.select_dtypes("float")
# Out:
#       Ali Log S  Ali Solubility (mg/ml)  Ali Solubility (mol/l)  \
# 0        -32.61            2.960000e-30            2.480000e-33
# 1         -5.13            8.840000e-03            7.400000e-06
# 2         -6.01            1.170000e-03            9.800000e-07
# 3        -27.92            1.350000e-25            1.210000e-28
# 4        -26.06            8.140000e-24            8.630000e-27
# 5         -8.31            4.260000e-06            4.940000e-09
# 6         -9.89            1.100000e-07            1.290000e-10
# 7        -16.33            3.700000e-14            4.730000e-17
# 8        -16.66            1.710000e-14            2.190000e-17
# 9        -20.55            2.260000e-18            2.820000e-21
# 10       -11.04            7.090000e-09            9.170000e-12
# 11       -11.61            1.890000e-09            2.450000e-12
# 12       -15.55            2.290000e-13            2.830000e-16
# 13       -13.16            5.240000e-11            6.930000e-14
# ...

# %% [markdown]
# column elements

# %%
DF.Library.unique()
# Out:
# array(['Afro', 'Biofacquim', 'FDA'], dtype=object)

# %% [markdown]
# count column elements

# %%
DF.Library.value_counts()
# Out:
# Afro          903
# FDA           690
# Biofacquim    423
# Name: Library, dtype: int64

# %% [markdown]
# column names

# %%
column_names = DF.columns.to_list()
column_names[:5]
# Out:
# ['#Aromatic heavy atoms',
#  '#H-bond acceptors',
#  '#H-bond donors',
#  '#Heavy atoms',
#  '#Rotatable bonds']

# %% [markdown]
# drop a column

# %%
DF = DF.drop('#Aromatic heavy atoms', axis = 1)
DF.head()
# Out:
#    #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                  7               3            85                52
# 1                 27              14            83                19
# 2                 26              14            83                17
# 3                 14               3            79                63
# 4                  8               3            67                54
#
#             Ali Class  Ali Log S  Ali Solubility (mg/ml)  \
# 0           Insoluble     -32.61            2.960000e-30
# 1  Moderately soluble      -5.13            8.840000e-03
# 2      Poorly soluble      -6.01            1.170000e-03
# 3           Insoluble     -27.92            1.350000e-25
# 4           Insoluble     -26.06            8.140000e-24
#
#    Ali Solubility (mol/l) BBB permeant  Bioavailability Score  ...  \
# 0            2.480000e-33           No                   0.17  ...
# 1            7.400000e-06           No                   0.17  ...
# ...

# %% [markdown]
# ## Conditional Selection

# %%
d = ['#Heavy atoms','#H-bond acceptors']

# %%
DF[d].head()
# Out:
#    #Heavy atoms  #H-bond acceptors
# 0            85                  7
# 1            83                 27
# 2            83                 26
# 3            79                 14
# 4            67                  8

# %%
DF[(DF["Library"] == "Biofacquim")]
# Out:
#       #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 903                   5               1            21                 2
# 904                   5               2            15                 3
# 905                   4               2            13                 2
# 906                  10               5            34                 7
# 907                   5               3            20                 3
# 908                   2               2             9                 0
# 909                   6               1            24                 3
# 910                   6               1            23                 3
# 911                   5               2            18                 1
# 912                   3               1            11                 2
# 913                   5               3            20                 0
# 914                   1               1            16                 4
# ...

# %%
DF[DF["#H-bond acceptors"]>5]
# Out:
#       #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                     7               3            85                52
# 1                    27              14            83                19
# 2                    26              14            83                17
# 3                    14               3            79                63
# 4                     8               3            67                54
# 6                    17              14            62                 5
# 7                     8               5            58                12
# 8                     8               6            58                11
# 9                     7               4            58                32
# 10                   10               7            57                 5
# 11                   10               6            57                 6
# 12                   14               3            57                41
# ...

# %%
DF[DF["Ali Class"]=="Insoluble"]
# Out:
#       #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                     7               3            85                52
# 3                    14               3            79                63
# 4                     8               3            67                54
# 7                     8               5            58                12
# 8                     8               6            58                11
# 9                     7               4            58                32
# 10                   10               7            57                 5
# 11                   10               6            57                 6
# 12                   14               3            57                41
# 13                    9               7            56                 5
# 14                   10               8            56                 5
# 15                   10               7            56                 5
# ...

# %% [markdown]
# two conditions

# %%
#DF[()&()]
DF[(DF["#H-bond acceptors"] < 5)&(DF["Ali Class"] == "Soluble")]
# Out:
#       #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 472                   4               1            28                 1
# 503                   4               1            27                 5
# 539                   4               0            26                 2
# 561                   4               0            25                 0
# 616                   3               2            24                 1
# 660                   2               1            23                 0
# 664                   4               1            23                 1
# 679                   4               1            23                 2
# 684                   4               0            23                 3
# 694                   4               1            23                 0
# 707                   2               0            22                 0
# 710                   4               1            22                 2
# ...

# %%
DF_VS = DF[(DF["#H-bond acceptors"] < 5)&(DF["Ali Class"] == "Soluble")]

# %%
DF_VS
# Out:
#       #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 472                   4               1            28                 1
# 503                   4               1            27                 5
# 539                   4               0            26                 2
# 561                   4               0            25                 0
# 616                   3               2            24                 1
# 660                   2               1            23                 0
# 664                   4               1            23                 1
# 679                   4               1            23                 2
# 684                   4               0            23                 3
# 694                   4               1            23                 0
# 707                   2               0            22                 0
# 710                   4               1            22                 2
# ...

# %% [markdown]
# reset index

# %%
DF_VS = DF_VS.reset_index()
DF_VS
# Out:
#      index  #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0      472                  4               1            28                 1
# 1      503                  4               1            27                 5
# 2      539                  4               0            26                 2
# 3      561                  4               0            25                 0
# 4      616                  3               2            24                 1
# 5      660                  2               1            23                 0
# 6      664                  4               1            23                 1
# 7      679                  4               1            23                 2
# 8      684                  4               0            23                 3
# 9      694                  4               1            23                 0
# 10     707                  2               0            22                 0
# ...

# %% [markdown]
# .loc

# %%
DF.loc[:1]
# Out:
#    #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                  7               3            85                52
# 1                 27              14            83                19
#
#             Ali Class  Ali Log S  Ali Solubility (mg/ml)  \
# 0           Insoluble     -32.61            2.960000e-30
# 1  Moderately soluble      -5.13            8.840000e-03
#
#    Ali Solubility (mol/l) BBB permeant  Bioavailability Score  ...  \
# 0            2.480000e-33           No                   0.17  ...
# 1            7.400000e-06           No                   0.17  ...
#
#    Silicos-IT Solubility (mg/ml) Silicos-IT Solubility (mol/l)  \
# 0                   2.920000e-18                  2.440000e-21
# 1                   1.260000e+07                  1.050000e+04
#
#   Silicos-IT class Synthetic Accessibility    TPSA Veber #violations  WLOGP  \
# 0        Insoluble                    10.0  105.45                 1  22.41
# ...

# %%
DF.loc[0]["#H-bond acceptors"]
# Out:
# 7

# %%
DF.iloc[0] #position
# Out:
# #H-bond acceptors                                                                7
# #H-bond donors                                                                   3
# #Heavy atoms                                                                    85
# #Rotatable bonds                                                                52
# Ali Class                                                                Insoluble
# Ali Log S                                                                   -32.61
# Ali Solubility (mg/ml)                                                    2.96e-30
# Ali Solubility (mol/l)                                                    2.48e-33
# BBB permeant                                                                    No
# Bioavailability Score                                                         0.17
# Brenk #alerts                                                                    1
# ...

# %% [markdown]
# # Missing Data

# %% [markdown]
# read a new DF

# %%
DF_MD = pd.read_csv("DF_MissingData.csv", sep = ",")

# %%
DF_MD
# Out:
#      #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                    5             NaN           NaN                 2
# 1                    5             2.0          15.0                 3
# 2                    4             2.0          13.0                 2
# 3                   10             5.0          34.0                 7
# 4                    5             3.0          20.0                 3
# 5                    2             2.0           9.0                 0
# 6                    6             1.0          24.0                 3
# 7                    6             1.0          23.0                 3
# 8                    5             2.0          18.0                 1
# 9                    3             1.0          11.0                 2
# 10                   5             3.0          20.0                 0
# 11                   1             1.0          16.0                 4
# ...

# %%
DF_MD.isnull()
# Out:
#      #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                False            True          True             False
# 1                False           False         False             False
# 2                False           False         False             False
# 3                False           False         False             False
# 4                False           False         False             False
# 5                False           False         False             False
# 6                False           False         False             False
# 7                False           False         False             False
# 8                False           False         False             False
# 9                False           False         False             False
# 10               False           False         False             False
# 11               False           False         False             False
# ...

# %%
DF_MD['#H-bond donors'] = DF_MD['#H-bond donors'].
fillna(value=DF_MD['#H-bond donors'].mean())
# Out:
#   File "<ipython-input-49-b45d59898234>", line 1
#     DF_MD['#H-bond donors'] = DF_MD['#H-bond donors'].
#                                                       ^
# SyntaxError: invalid syntax

# %%
DF_MD
# Out:
#      #H-bond acceptors  #H-bond donors  #Heavy atoms  #Rotatable bonds  \
# 0                    5        2.632458           NaN                 2
# 1                    5        2.000000          15.0                 3
# 2                    4        2.000000          13.0                 2
# 3                   10        5.000000          34.0                 7
# 4                    5        3.000000          20.0                 3
# 5                    2        2.000000           9.0                 0
# 6                    6        1.000000          24.0                 3
# 7                    6        1.000000          23.0                 3
# 8                    5        2.000000          18.0                 1
# 9                    3        1.000000          11.0                 2
# 10                   5        3.000000          20.0                 0
# 11                   1        1.000000          16.0                 4
# ...
